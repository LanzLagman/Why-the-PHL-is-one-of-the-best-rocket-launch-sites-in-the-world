# %% [markdown]
# # Why the PHL is one of the best rocket launch sites in the world
# ## Article published in March 9, 2017 6:40pm @ GMA News SciTech
#
# Link: http://www.gmanetwork.com/news/scitech/science/602582/why-the-phl-is-one-of-the-best-rocket-launch-sites-in-the-world/story/

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt

Isp = 280 #specific impulse
mr = 105000 #rocket mass without fuel
rE = 6371000 # earth radius
a = 400000 #altitude
G = 6.67408e-11#grav constant
ME = 5.972e24 #earth mass
w = 7.29210e-5 #earth angular velocity
g0 = 9.8 #acceleration due to gravity

# %%
from IPython.display import Math
Math(r'm_f(\Phi) = m_r\Bigg({e}^{\frac{\sqrt{\frac{GM_E}{R_E + a}}- R_E \omega \cos\Phi}{i_{sp}g_o}}-1\Bigg)')
# Out:
# $$m_f(\Phi) = m_r\Bigg({e}^{\frac{\sqrt{\frac{GM_E}{R_E + a}}- R_E \omega \cos\Phi}{i_{sp}g_o}}-1\Bigg)$$

# %%
def fuel(lat):
    return mr*(np.exp((np.sqrt((G*ME)/(rE + a)) - rE*w*np.cos(np.radians(lat)))/(Isp*g0))-1)

# %% [markdown]
# Test first if function `fuel` works

# %%
ph_lat = 13 #deg

fuel(ph_lat)
# Out:
# 1353324.1722077604

# %% [markdown]
# Then, clean your function and proceed to plotting.

# %%
def fuel(lat):
    #radial velocity, vr
    vr = np.sqrt((G*ME)/(rE + a))
    #tangential velocity, vt
    
    vt = rE*w*np.cos(np.radians(lat))
    vtj = rE*w*np.cos(np.radians(30))

    fraction = (vr - vt)/(Isp*g0)
    fraction1 = (vr - vtj)/(Isp*g0)
    
    return mr*(np.exp(fraction)-1)
    print (mr*(np.exp(fraction1)-1))

# %%
import numpy as np
import matplotlib.pyplot as plt

lat = np.arange(-100.0,100.0,0.10)
#plot all
plt.plot(lat, fuel(lat)/1e3, 'k-')
#plot PH

ph_lat = 7.5225 #Zamboanga Sibugay
capcav_lat = 28.474 #Cape Canaveral
Puntalobos_lat = -12.5 #Punta Lobos
Plesetsk_lat = 62.9279
Overberg_lat = -34.6027
Tanegashima_lat = 30.39
Wenchang_lat = 19.614492
StasiunPeluncuran_lat=-7.6466
Puerto_Belgrano=-38.9

plt.title('Rocket Fuel Expenditure vs Latitude for m$_r$ = 1.5 x 10$^5$ kg, a = 400 km')

#plt.plot(ph_lat, fuel(ph_lat)/1e3, 'ro')


plt.plot(ph_lat, fuel(ph_lat)/1e3, 'ro', label='Zamboanga Sibugay, Philippines (Hypothetical launch site) ' )
plt.plot(capcav_lat, fuel(capcav_lat)/1e3, 'bo', label='Cape Canaveral Air Force Station, USA' )
plt.plot(Puntalobos_lat, fuel(Puntalobos_lat)/1e3, 'co', label='Punta Lobos, Peru' )
plt.plot(Plesetsk_lat, fuel(Plesetsk_lat)/1e3, 'mo', label='Plesetsk Cosmodrome, Russia' )
plt.plot(Tanegashima_lat, fuel(Tanegashima_lat)/1e3, 'ko', label='Tanegashima Space Center, Japan ' )
plt.plot(Wenchang_lat, fuel(Wenchang_lat)/1e3, 'yo', label='Wenchang Satellite Launch Center, China' )
plt.plot(StasiunPeluncuran_lat, fuel(StasiunPeluncuran_lat)/1e3, 'wo', label='Stasiun Peluncuran Roket, Indonesia ' )
plt.plot(Puerto_Belgrano, fuel(Puerto_Belgrano)/1e3, 'go', label='Puerto Belgrano, Argentina' )

'''
plt.plot(ph_lat, fuel(ph_lat)/1e3, 'ro', label='Zamboanga Sibugay, Philippines (Hypothetical launch site),7.5225 N$^\circ$ ' )
plt.plot(30, fuel(30)/1e3, 'ko', label='Example Launch Site near Japan, 30 N$^\circ$' )
'''
plt.xlabel('Latitude (N$^\circ$)')
plt.ylabel('Rocket Fuel (in 10$^3$ kg)')
plt.ylim(1300,1700)
plt.xlim(-90, 90)

plt.legend(loc='upper center', numpoints=1, prop={'size':7})
plt.show()

# %% [markdown]
# # UPDATE

# %% [markdown]
# # Plot

# %% [markdown]
# Reference: https://github.com/LanzLagman/Plotting-Rocket-Launch-Sites-with-Folium

# %%
import pandas as pd
import wikipedia as wp

# %%
html = wp.page("List of rocket launch sites").html().encode("UTF-32")

# %%
Africa = pd.read_html(html, header=0)[2]
Africa['Loc_string'] = Africa['Coordinates'].apply(lambda name: name.split('\ufeff / ')[-1])
Africa['Location'] = Africa['Location'].apply(lambda name: name.split('[')[0])
Africa['Latitude'] = Africa['Loc_string'].apply(lambda name: name.split(';')[0]).astype(float)
Africa['Longitude'] = Africa['Loc_string'].apply(lambda name: name.split()[1].rstrip('\ufeff')).astype(float)

# %%
Asia = pd.read_html(html, header=0)[3]
Asia['Loc_string'] = Asia['Coordinates'].apply(lambda name: name.split('\ufeff / ')[-1])
Asia['Location'] = Asia['Location'].apply(lambda name: name.split('[')[0])
Asia['Latitude'] = Asia['Loc_string'].apply(lambda name: name.split(';')[0]).astype(float)
Asia['Longitude'] = Asia['Loc_string'].apply(lambda name: name.split()[1].rstrip('\ufeff')).astype(float)

# %%
Europe = pd.read_html(html, header=0)[4]
Europe['Loc_string'] = Europe['Coordinates'].apply(lambda name: name.split('\ufeff / ')[-1])
Europe['Location'] = Europe['Location'].apply(lambda name: name.split('[')[0])
Europe['Latitude'] = Europe['Loc_string'].apply(lambda name: name.split(';')[0]).astype(float)
Europe['Longitude'] = Europe['Loc_string'].apply(lambda name: name.split()[1].rstrip('\ufeff')).astype(float)

# %%
N_America = pd.read_html(html, header=0)[5]
N_America['Loc_string'] = N_America['Coordinates'].apply(lambda name: name.split('\ufeff / ')[-1])
N_America['Location'] = N_America['Location'].apply(lambda name: name.split('[')[0])
N_America['Latitude'] = N_America['Loc_string'].apply(lambda name: name.split(';')[0]).astype(float)
N_America['Longitude'] = N_America['Loc_string'].apply(lambda name: name.split()[1].rstrip('\ufeff')).astype(float)

# %%
S_America = pd.read_html(html, header=0)[7]
S_America['Loc_string'] = S_America['Coordinates'].apply(lambda name: name.split('\ufeff / ')[-1])
S_America['Location'] = S_America['Location'].apply(lambda name: name.split('[')[0])
S_America['Latitude'] = S_America['Loc_string'].apply(lambda name: name.split(';')[0]).astype(float)
S_America['Longitude'] = S_America['Loc_string'].apply(lambda name: name.split()[1].rstrip('\ufeff')).astype(float)

# %%
Oceania = pd.read_html(html, header=0)[8]
Oceania['Loc_string'] = Oceania['Coordinates'].apply(lambda name: name.split('\ufeff / ')[-1])
Oceania['Location'] = Oceania['Location'].apply(lambda name: name.split('[')[0])
Oceania['Latitude'] = Oceania['Loc_string'].apply(lambda name: name.split(';')[0]).astype(float)
Oceania['Longitude'] = Oceania['Loc_string'].apply(lambda name: name.split()[1].rstrip('\ufeff')).astype(float)

# %% [markdown]
# ## Update each dataframes

# %%
Africa['plot_color'] = str('black')
Asia['plot_color'] = str('orange')
Europe['plot_color'] = str('blue')
N_America['plot_color'] = str('red')
S_America['plot_color'] = str('red')
Oceania['plot_color'] = str('green')

# %%
Africa['Continent'] = str('Africa')
Asia['Continent'] = str('Asia')
Europe['Continent'] = str('Europe')
N_America['Continent'] = str('North America')
S_America['Continent'] = str('South America')
Oceania['Continent'] = str('Australia and Oceania')

# %% [markdown]
# ## Combine by concat

# %%
World = pd.concat([Africa, Asia, Europe, N_America, S_America, Oceania], ignore_index=True)
World
# Out:
#               Country                                           Location  \
# 0             Algeria  Hammaguira French Special Weapons Test Centre,...
# 1             Algeria                                            Reggane
# 2       Congo (Zaire)     Shaba North, Kapani Tonneo OTRAG Launch Center
# 3               Egypt  Jabal Hamzah ballistic missile test and launch...
# 4               Kenya          Broglio Space Centre (San Marco), Malindi
# 5               Libya                  Sabha, Tawiwa OTRAG Launch Center
# 6          Mauritania                                         Nouadhibou
# 7        South Africa                 Overberg South African Test Centre
# 8               China                        Base 603, Shijiedu, Guangde
# 9               China                    Jiuquan Satellite Launch Center
# 10              China                    Taiyuan Satellite Launch Center
# 11              China                    Xichang Satellite Launch Center
# 12              China                   Wenchang Satellite Launch Center
# 13              China                                             Jingyu
# 14              India  Vikram Sarabhai Space Centre, Thiruvananthapur...
# 15              India  Satish Dhawan Space Centre (Sriharikota), Andh...
# 16              India                                 Abdul Kalam Island
# 17          Indonesia       Stasiun Peluncuran Roket, Pameungpeuk, Garut
# 18               Iran                                   Qom Space Center
# 19               Iran                             Emamshahr Space Center
# 20               Iran                                   Semnan spaceport
# 21               Iraq                               Al-Anbar Test Center
# 22             Israel                           Palmachim Air Force Base
# 23              Japan                                 Akita Rocket Range
# 24              Japan                             Uchinoura Space Center
# 25              Japan       Tanegashima Space Center, Tanegashima Island
# 26              Japan                                              Ryori
# 27              Japan                                       Niijima (ja)
# 28              Japan                                             Obachi
# 29         Kazakhstan                      Baikonur Cosmodrome, Tyuratam
# ..                ...                                                ...
# 80      United States              Vandenberg Air Force Base, California
# 81      United States                      Kennedy Space Center, Florida
# 82      United States             Pacific Missile Range Facility, Hawaii
# 83      United States                                 Keweenaw, Michigan
# 84      United States                      Kodiak Launch Complex, Alaska
# 85      United States              Mojave Air and Space Port, California
# 86      United States  Spaceport America (formerly Southwest Regional...
# 87      United States  Mid-Atlantic Regional Spaceport (MARS), Delmar...
# 88          Argentina                                    Puerto Belgrano
# 89          Argentina                                        Punta Indio
# 90          Argentina                                              CELPA
# 91          Argentina                                         Serrezuela
# 92          Argentina                                         Las Palmas
# 93          Argentina                                           Tartagal
# 94          Argentina                                       Mar Chiquita
# 95          Argentina                                     Villa Reynolds
# 96          Argentina                                    Pampa de Achala
# 97             Brazil                                     Natal/Barreira
# 98             Brazil                                   Praia do Cassino
# 99             Brazil                  Alcântara Launch Center, Maranhão
# 27                          NaN                       NaN
# 28                          NaN                       NaN
# 29                        1957–                     >1000
# ..                          ...                       ...
# 80                        1958–                       NaN
# 81                        1963–                       151
# 82                        1963–                       NaN
# 83   1964–1971[citation needed]                       >50
# 84                        1991–                        14
# 85                        2004–                       NaN
# 86                        2006–                         8
# 87                        2006–                         6
# 88                          TBA                       NaN
# 89                        2014–                         3
# 90            1962–1974 / 2011–       100 (approximately)
# 91                         2009                         1
# 92                    1966–1966                         2
# 93                    1966–1966                       NaN
# 94                    1968–1972                        11
# 95                    1973–1973                         2
# 96                    1961–1962                         8
# 97                        1965–                       233
# 98                    1966–1966                        27
# 99                        1990–                        35
# 100                       1968–                      <200
# 101                   1974-1983                       <65
# 102                        1983                        32
# 103                   1965–1965                         4
# 104                      1950s–                       NaN
# 105                   1964–1965                        12
# 106                   1974–1974                         2
# 107                      1950s-                       NaN
# 108                         NaN                       NaN
# 109                       2017–                         2
#
#     Heaviest rocket launched Highest achieved altitude  \
# 0                  18 000 kg                   Orbital
# 1                        NaN                       NaN
# 2                        NaN                    <50 km
# 3                        NaN                       NaN
# 4                  20 000 kg                   Orbital
# 5                        NaN                     50 km
# 6                        NaN                       NaN
# 7                        NaN                       NaN
# 8                   1 000 kg                    <60 km
# 9                 464 000 kg                   Orbital
# 10                       NaN                   Orbital
# 11                       NaN                     Lunar
# 12                879 000 kg                   Orbital
# 13                       NaN                       NaN
# 14                       NaN                       NaN
# 15                402 000 kg            Interplanetary
# 16                       NaN                       NaN
# 17                    765 kg                    100 km
# 18                       NaN                       NaN
# 19                       NaN                       NaN
# 20                       NaN                   Orbital
# 21                       NaN                       NaN
# 22                 70 000 kg                   Orbital
# 23                       NaN                    343 km
# 24                139 000 kg            Interplanetary
# 25                445 000 kg            Interplanetary
# 26                       NaN                       NaN
# 27                       NaN                       NaN
# 28                       NaN                       NaN
# 29              2 400 000 kg            Interplanetary
# ..                       ...                       ...
# 80                       NaN                   Orbital
# 81              3 000 000 kg            Interplanetary
# 82                       NaN                       NaN
# 83                    770 kg                   <160 km
# 84                 86 000 kg                   Orbital
# 85                       NaN                    112 km
# 86                       NaN                       NaN
# 87                 89 805 kg                     Lunar
# 88                       NaN                       NaN
# 89             7 076 kg [65]                    2.2 km
# 90                    933 kg                    550 km
# 91                    500 kg                     40 km
# 92                  3 400 kg                    270 km
# 93                       NaN                       NaN
# 94                       NaN                       NaN
# 95                       NaN                       NaN
# 96                     28 kg                     25 km
# 97                       NaN                   1100 km
# 98                       NaN                       NaN
# 99                  6 737 kg                    956 km
# 100               777 000 kg            Interplanetary
# 101                      NaN                    590 km
# 102                 2 000 kg                    590 km
# 103                      NaN                    205 km
# 104                28 000 kg                   Orbital
# 105                      NaN                    120 km
# 106                      NaN                       NaN
# 107                39 000 kg                   Orbital
# 108                      NaN                       NaN
# 109                10 500 kg                   Orbital
#
#                                                  Notes  \
# 0                               Operated by France.[1]
# 1                                                  NaN
# 2                             German OTRAG rockets.[2]
# 3            Al Zafir and Al Kahir SRBMs testing[3][4]
# 4    Scout rockets, operated by ASI and Sapienza Un...
# 5                             German OTRAG rockets.[6]
# 6                               During a solar eclipse
# 7               Launched test mission rockets only.[7]
# 8                                                  NaN
# 9                                 Human spaceflight[8]
# 10                                 Polar satellites[9]
# 11   Geo-synchronous satellites, lunar probes.[10][11]
# 12   New site on Hainan Island with pads for Long M...
# 13                                                 NaN
# 14                                                [12]
# 15                    Satellites and lunar probes;[13]
# 16                                                 NaN
# 17                                                 NaN
# 18                                Military testing[14]
# 19   Military testing and sounding rockets for ISA....
# 20                                                 NaN
# 21                                 Out of function[16]
# 22                                                [17]
# 23                                                 NaN
# 24                                                [18]
# 25                                                [19]
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29   First satellite, first human. Operated by Russ...
# ..                                                 ...
# 80   Satellites, ballistic missile tests. Governmen...
# 81   Launched each NASA manned mission. Adjacent to...
# 82   testing of antiballistic missile and missile t...
# 83                                  Currently inactive
# 84   Ballistic missile interceptor tests, satellite...
# 85   Privately funded spacecraft (Xoie, Xombie, Xod...
# 86   Sub-orbital commercial and planned space touri...
# 87   Operates in partnership with NASA, adjacent to...
# 88   Launch pad for Tronador II under construction ...
# 89                   Civilian Launch Test Site (CONAE)
# 90                 Military Launch Test Site (CITIDEF)
# 91                          Military test (Gradicom I)
# 92         During a solar eclipse, with Titus rockets.
# 93                              During a solar eclipse
# 94                                                 NaN
# 95                                                 NaN
# 96                        First Argentine launch site.
# 97                                                 NaN
# 98                                                 NaN
# 99   Brazilian Air Force, Brazilian Space Agency. P...
# 100  Operated by CNES for ESA; launch base for Aria...
# 101               Sounding rocket launch location.[66]
# 102  Sounding rocket launch location. Possibly part...
# 103                                                NaN
# 104  British/Australian government research facilit...
# 105                                                NaN
# 106                       During a total solar eclipse
# 107  US-controlled ICBM base converted for satellit...
# 108  Formerly proposed launch site for Rocket Lab, ...
# 109  First commercial spaceport in the southern hem...
#
#                                             Loc_string   Latitude   Longitude  \
# 0                      31.09951; -2.83581﻿ (Hammaguir)  31.099510   -2.835810
# 1                         26.71895; 0.27691﻿ (Reggane)  26.718950    0.276910
# 2                  -7.92587; 28.52766﻿ (Kapani Tonneo)  -7.925870   28.527660
# 3                 30.125750; 30.605139﻿ (Jabal Hamzah)  30.125750   30.605139
# 4             -2.94080; 40.21340﻿ (San Marco platform)  -2.940800   40.213400
# 5                          26.99392; 14.46425﻿ (Sabha)  26.993920   14.464250
# 6                    20.92856; -17.03153﻿ (Nouadhibou)  20.928560  -17.031530
# 7                      -34.60265; 20.30248﻿ (Overberg) -34.602650   20.302480
# 8                      30.93743; 119.20575﻿ (Shijiedu)  30.937430  119.205750
# 9                       41.11803; 100.46330﻿ (Jiuquan)  41.118030  100.463300
# 10                      39.14321; 111.96741﻿ (Taiyuan)  39.143210  111.967410
# 11                      28.24646; 102.02814﻿ (Xichang)  28.246460  102.028140
# 12                 19.6144917; 110.9511333﻿ (Wenchang)  19.614492  110.951133
# 13                               42.0; 126.5﻿ (Jingyu)  42.000000  126.500000
# 14     8.5314; 76.8690﻿ (Vikram Sarabhai Space Centre)   8.531400   76.869000
# 15                   13.73740; 80.23510﻿ (Sriharikota)  13.737400   80.235100
# 16           20.75804; 87.085533﻿ (Abdul kalam Island)  20.758040   87.085533
# 17                -7.646643; 107.689018﻿ (Pameungpeuk)  -7.646643  107.689018
# 18                           34.65000; 50.90000﻿ (Qom)  34.650000   50.900000
# 19                     36.42000; 55.02000﻿ (Emamshahr)  36.420000   55.020000
# 20                      35.234631; 53.920941﻿ (Semnan)  35.234631   53.920941
# 21                      32.78220; 44.29962﻿ (Al-Anbar)  32.782200   44.299620
# 22                     31.88484; 34.68020﻿ (Palmachim)  31.884840   34.680200
# 23                        39.57148; 140.05785﻿ (Akita)  39.571480  140.057850
# 24                    31.25186; 131.07914﻿ (Uchinoura)  31.251860  131.079140
# 25                  30.39096; 130.96813﻿ (Tanegashima)  30.390960  130.968130
# 26                        39.03000; 141.83000﻿ (Ryori)  39.030000  141.830000
# 27                      34.33766; 139.26575﻿ (Niijima)  34.337660  139.265750
# 28                       40.70342; 141.36938﻿ (Obachi)  40.703420  141.369380
# 29                      45.95515; 63.35028﻿ (Baikonur)  45.955150   63.350280
# ..                                                 ...        ...         ...
# 80                  34.77204; -120.60124﻿ (Vandenberg)  34.772040 -120.601240
# 81           28.6082; -80.6040﻿ (Kennedy Space Center)  28.608200  -80.604000
# 82                                22.02278; -159.78500  22.022780 -159.785000
# 83                     47.42980; -87.71443﻿ (Keweenaw)  47.429800  -87.714430
# 84                      57.43533; -152.33931﻿ (Kodiak)  57.435330 -152.339310
# 85                      35.05910; -118.14880﻿ (Mojave)  35.059100 -118.148800
# 86           32.88943; -106.99945﻿ (Spaceport America)  32.889430 -106.999450
# 87   37.833378; -75.483284﻿ (Mid-Atlantic Regional ...  37.833378  -75.483284
# 88                -38.9628; -61.715﻿ (Puerto Belgrano) -38.962800  -61.715000
# 89               -35.523889; -57.183889﻿ (Punta Indio) -35.523889  -57.183889
# 90                       -30.12737; -66.34082﻿ (CELPA) -30.127370  -66.340820
# 91                    -30.6333; -65.3833﻿ (Serrezuela) -30.633300  -65.383300
# 92                  -27.09531; -58.75352﻿ (Las Palmas) -27.095310  -58.753520
# 93                    -22.76158; -63.82381﻿ (Tartagal) -22.761580  -63.823810
# 94                -37.72427; -57.40512﻿ (Mar Chiquita) -37.724270  -57.405120
# 95              -33.72460; -65.37730﻿ (Villa Reynolds) -33.724600  -65.377300
# 96               -31.5833; -64.8333﻿ (Pampa de Achala) -31.583300  -64.833300
# 97                        -5.86600; -35.38300﻿ (Natal)  -5.866000  -35.383000
# 98            -32.08338; -52.16725﻿ (Praia do Cassino) -32.083380  -52.167250
# 99                      -2.3160; -44.3676﻿ (Alcantara)  -2.316000  -44.367600
# 100                       5.23739; -52.76950﻿ (Kourou)   5.237390  -52.769500
# 101        -12.50477; -76.79849﻿ (Chilca Launch Range) -12.504770  -76.798490
# 102           -12.50000; -76.8000﻿ (Punta Lobos Range) -12.500000  -76.800000
# 103                      5.87241; -56.28908﻿ (Coronie)   5.872410  -56.289080
# 104                    -30.95875; 136.50366﻿ (Woomera) -30.958750  136.503660
# 105                  -24.48564; 113.40866﻿ (Carnarvon) -24.485640  113.408660
# 106                   -30.98309; 115.31774﻿ (Lancelin) -30.983090  115.317740
# 107                     9.048167; 167.743083﻿ (Omelek)   9.048167  167.743083
# 108                  -43.81700; 172.68300﻿ (Carnarvon) -43.817000  172.683000
# 109                      -39.26044; 177.86431﻿ (Mahia) -39.260440  177.864310
#
#     plot_color              Continent
# 0        black                 Africa
# 1        black                 Africa
# 2        black                 Africa
# 3        black                 Africa
# 4        black                 Africa
# 5        black                 Africa
# 6        black                 Africa
# 7        black                 Africa
# 8       orange                   Asia
# 9       orange                   Asia
# 10      orange                   Asia
# 11      orange                   Asia
# 12      orange                   Asia
# 13      orange                   Asia
# 14      orange                   Asia
# 15      orange                   Asia
# 16      orange                   Asia
# 17      orange                   Asia
# 18      orange                   Asia
# 19      orange                   Asia
# 20      orange                   Asia
# 21      orange                   Asia
# 22      orange                   Asia
# 23      orange                   Asia
# 24      orange                   Asia
# 25      orange                   Asia
# 26      orange                   Asia
# 27      orange                   Asia
# 28      orange                   Asia
# 29      orange                   Asia
# ..         ...                    ...
# 80         red          North America
# 81         red          North America
# 82         red          North America
# 83         red          North America
# 84         red          North America
# 85         red          North America
# 86         red          North America
# 87         red          North America
# 88         red          South America
# 89         red          South America
# 90         red          South America
# 91         red          South America
# 92         red          South America
# 93         red          South America
# 94         red          South America
# 95         red          South America
# 96         red          South America
# 97         red          South America
# 98         red          South America
# 99         red          South America
# 100        red          South America
# 101        red          South America
# 102        red          South America
# 103        red          South America
# 104      green  Australia and Oceania
# 105      green  Australia and Oceania
# 106      green  Australia and Oceania
# 107      green  Australia and Oceania
# 108      green  Australia and Oceania
# 109      green  Australia and Oceania
#
# [110 rows x 13 columns]

# %%
import folium
from folium.plugins import MarkerCluster

# %%
Map = folium.Map(location=[0,0], height=525, width=650, tiles="OpenStreetMap", 
                   zoom_start=1)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in np.arange(len(World)):
    folium.CircleMarker([World['Latitude'][i], World['Longitude'][i]], 
                  radius=2.5, color=World['plot_color'][i], fill=True, fill_color=World['plot_color'][i], fill_opacity=0.5,
                  popup=folium.Popup('{0} \n Coordinates: {1}'.format(World['Location'].values[i], 
                         World['Coordinates'][i].split('\ufeff / ')[0]),parse_html=True)
                  ).add_to(Map)

Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
World[World['Number of rocket launches']=='>2000']
# Out:
#    Country                                           Location  \
# 14   India  Vikram Sarabhai Space Centre, Thiruvananthapur...
#
#                                           Coordinates Operational date  \
# 14  8°31′53″N 76°52′08″E﻿ / ﻿8.5314°N 76.8690°E﻿ /...            1962–
#
#    Number of rocket launches Heaviest rocket launched  \
# 14                     >2000                      NaN
#
#    Highest achieved altitude Notes  \
# 14                       NaN  [12]
#
#                                          Loc_string  Latitude  Longitude  \
# 14  8.5314; 76.8690﻿ (Vikram Sarabhai Space Centre)    8.5314     76.869
#
#    plot_color Continent
# 14     orange      Asia

# %% [markdown]
# ## What if the Philippines had a rocket launch site?

# %%
#Asia_w_Phl =

# %%
Asia.tail(1)
# Out:
#    Country Location                                        Coordinates  \
# 36  Taiwan  Haiqian  22°06′N 120°54′E﻿ / ﻿22.10°N 120.90°E﻿ / 22.10...
#
#    Operational date Number of rocket launches Heaviest rocket launched  \
# 36            1988–                       NaN                10 000 kg
#
#    Highest achieved altitude                               Notes  \
# 36                    300 km  Science and technology development
#
#                  Loc_string  Latitude  Longitude plot_color Continent
# 36  22.10; 120.90﻿ (Gangzi)      22.1      120.9     orange      Asia

# %%
Phl = pd.DataFrame(['Philippines', 'Sarangani', np.nan, np.nan, np.nan], columns=Asia.columns)
